# %%
from Forces2 import Forces2 as Forces

testFile = "data/forcesv1706.dat"
f = open(testFile, "r")
for line in f:
    print(line.split())

t = Forces("testFile", Verbose=True, startTime=0.5, endTime = 10)
# Out:
# ['#', 'Force']
# ['#', 'CofR', ':', '(0.0000000000e+00', '0.0000000000e+00', '0.0000000000e+00)']
# ['#']
# ['#', 'Time', '(total_x', 'total_y', 'total_z)', '(pressure_x', 'pressure_y', 'pressure_z)', '(viscous_x', 'viscous_y', 'viscous_z)']
# ['0.001', '(1.6369386298e+00', '-4.1763076066e-01', '-4.4830173374e+01)', '(1.6150827671e+00', '-4.1793195037e-01', '-4.4820864600e+01)', '(2.1855862721e-02', '3.0118970715e-04', '-9.3087742424e-03)']
# ['0.002', '(-1.9869750167e-02', '2.9191851921e-02', '5.3436943394e-02)', '(-4.1065040446e-02', '2.8502105178e-02', '6.1722614815e-02)', '(2.1195290279e-02', '6.8974674327e-04', '-8.2856714202e-03)']
# ['0.003', '(1.3664139032e-02', '1.7619696578e-02', '-4.5949161027e-01)', '(-6.7039440654e-03', '1.6793629852e-02', '-4.5223810337e-01)', '(2.0368083097e-02', '8.2606672600e-04', '-7.2535068954e-03)']
# ...
